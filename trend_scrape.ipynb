# %%
from pytrends.request import TrendReq
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
pytrend = TrendReq(hl='en-US', tz=360)

# %%
# testing
pytrend.build_payload(kw_list=["james bond"], timeframe='2021-9-01 2021-10-10')
df = pytrend.interest_over_time()
df
# Out:
#             james bond  isPartial
# date
# 2021-09-01          12      False
# 2021-09-02          11      False
# 2021-09-03          12      False
# 2021-09-04          12      False
# 2021-09-05          11      False
# 2021-09-06          10      False
# 2021-09-07           9      False
# 2021-09-08           7      False
# 2021-09-09           8      False
# 2021-09-10          12      False
# 2021-09-11          11      False
# 2021-09-12          14      False
# 2021-09-13          10      False
# 2021-09-14          11      False
# 2021-09-15          10      False
# 2021-09-16          11      False
# 2021-09-17          12      False
# 2021-09-18          18      False
# 2021-09-19          17      False
# 2021-09-20          13      False
# 2021-09-21          13      False
# 2021-09-22          14      False
# 2021-09-23          16      False
# 2021-09-24          21      False
# 2021-09-25          23      False
# 2021-09-26          26      False
# 2021-09-27          24      False
# 2021-09-28          35      False
# 2021-09-29          56      False
# 2021-09-30          56      False
# 2021-10-01          68      False
# 2021-10-02          79      False
# 2021-10-03         100      False
# 2021-10-04          52      False
# 2021-10-05          45      False
# 2021-10-06          46      False
# 2021-10-07          47      False
# 2021-10-08          61      False
# 2021-10-09          85      False

# %%
# Import movie titles and release dates
movie_df =

# %%
# fix datetime conversion
for index, row in movie_df.iterrows():
    title = row["Title"] + " movie"
    release_date = row["Release_Date"]
    start_date = release_date - relativedelta(years=1)
    pytrend.build_payload(kw_list=[title], timeframe=f'{start_date} {release_date}')
    df = pytrend.interest_over_time()
    buzz = len(df.loc[df[title] >= 20])
    movie_df.loc[index, "Buzz"] = buzz

# %%
title = "justice league" + " movie"
release_date = "2017-11-17"
start_date_ojb = dt.datetime.strptime(release_date, '%Y-%m-%d') - relativedelta(years=1)
start_date = start_date_ojb.strftime('%Y-%m-%d')
timeframe = f'{start_date} {release_date}'
print(timeframe)
pytrend.build_payload(kw_list=[title], timeframe=timeframe)
df = pytrend.interest_over_time()
buzz = len(df.loc[df[title] >= 20])
#movie_df.loc[index, "Buzz"] = buzz
print(buzz)
df
# Out:
# 2016-11-17 2017-11-17
# 3
#             justice league movie  isPartial
# date
# 2016-11-20                     6      False
# 2016-11-27                     9      False
# 2016-12-04                     7      False
# 2016-12-11                     6      False
# 2016-12-18                     8      False
# 2016-12-25                     8      False
# 2017-01-01                     8      False
# 2017-01-08                     8      False
# 2017-01-15                     7      False
# 2017-01-22                    10      False
# 2017-01-29                     9      False
# 2017-02-05                    10      False
# 2017-02-12                     8      False
# 2017-02-19                     9      False
# 2017-02-26                     7      False
# 2017-03-05                     6      False
# 2017-03-12                     8      False
# 2017-03-19                    16      False
# 2017-03-26                    17      False
# 2017-04-02                     8      False
# 2017-04-09                     8      False
# 2017-04-16                     7      False
# 2017-04-23                     8      False
# 2017-04-30                     5      False
# 2017-05-07                     6      False
# 2017-05-14                     6      False
# 2017-05-21                     7      False
# 2017-05-28                    10      False
# 2017-06-04                    11      False
# 2017-06-11                     9      False
# 2017-06-18                     8      False
# 2017-06-25                     9      False
# 2017-07-02                     9      False
# 2017-07-09                     8      False
# 2017-07-16                    10      False
# 2017-07-23                    20      False
# 2017-07-30                    10      False
# 2017-08-06                    10      False
# 2017-08-13                     9      False
# 2017-08-20                     6      False
# 2017-08-27                     7      False
# 2017-09-03                     7      False
# 2017-09-10                     7      False
# 2017-09-17                     8      False
# 2017-09-24                     8      False
# 2017-10-01                    10      False
# 2017-10-08                    12      False
# 2017-10-15                    11      False
# 2017-10-22                    13      False
# 2017-10-29                    15      False
# 2017-11-05                    27      False
# 2017-11-12                   100      False

# %%
title = "mulan movie"
release_date = "2020-03-09"
start_date_ojb = dt.datetime.strptime(release_date, '%Y-%m-%d') - relativedelta(years=1)
start_date = start_date_ojb.strftime('%Y-%m-%d')
timeframe = f'{start_date} {release_date}'
print(timeframe)
pytrend.build_payload(kw_list=[title], timeframe=timeframe)
df = pytrend.interest_over_time()
buzz = len(df.loc[df[title] >= 20])
#movie_df.loc[index, "Buzz"] = buzz
print(buzz)
df
# Out:
# 2019-03-09 2020-03-09
# 21
#             mulan movie  isPartial
# date
# 2019-03-10           15      False
# 2019-03-17           12      False
# 2019-03-24            9      False
# 2019-03-31           11      False
# 2019-04-07           15      False
# 2019-04-14           10      False
# 2019-04-21           10      False
# 2019-04-28            9      False
# 2019-05-05           10      False
# 2019-05-12           12      False
# 2019-05-19           18      False
# 2019-05-26           15      False
# 2019-06-02           16      False
# 2019-06-09           11      False
# 2019-06-16           19      False
# 2019-06-23           12      False
# 2019-06-30           19      False
# 2019-07-07          100      False
# 2019-07-14           39      False
# 2019-07-21           38      False
# 2019-07-28           20      False
# 2019-08-04           19      False
# 2019-08-11           21      False
# 2019-08-18           22      False
# 2019-08-25           17      False
# 2019-09-01           16      False
# 2019-09-08           16      False
# 2019-09-15           18      False
# 2019-09-22           17      False
# 2019-09-29           13      False
# 2019-10-06           17      False
# 2019-10-13           15      False
# 2019-10-20           15      False
# 2019-10-27           16      False
# 2019-11-03           12      False
# 2019-11-10           16      False
# 2019-11-17           16      False
# 2019-11-24           10      False
# 2019-12-01           35      False
# 2019-12-08           29      False
# 2019-12-15           23      False
# 2019-12-22           24      False
# 2019-12-29           24      False
# 2020-01-05           25      False
# 2020-01-12           23      False
# 2020-01-19           24      False
# 2020-01-26           26      False
# 2020-02-02           34      False
# 2020-02-09           28      False
# 2020-02-16           26      False
# 2020-02-23           40      False
# 2020-03-01           55      False
# 2020-03-08           79      False
