# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
import numpy as np

# %%
#url = 'https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2006'

# %%
# Create a Beautiful Soup object
def scrape():
    pages = np.arange(1,501,100)
    years = np.arange(2006,2020,1)
    movies = []
    for year in years:
        #year = requests.get('https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-' + str(year))
        
        for page in pages:
            page = requests.get('https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-' + str(year) + '/' + str(page))
            soup = bs(page.text, 'html.parser')
            tds = soup.find_all('td')
            #print(tds)

            title = []
            
            # Loop over td elements
            for td in tds:
                # If td element has an anchor...
                if (td.b):
                    # And the anchor has non-blank text...
                    if (td.b.text):
                        # Append the td to the list
                        title.append(td)
            #print(headlines)
            
            for x in range(100):
                movies.append(title[x].text)
            #movies
            #print(movies)
    return(movies)

# %%
len(scrape())
# Out:
# 7000

# %%
scrape()
# Out:
# ['Pirates of the Caribbean: Dead Manâ\x80\x99s Chest',
#  'Night at the Museum',
#  'Cars',
#  'X-Men: The Last Stand',
#  'The Da Vinci Code',
#  'Superman Returns',
#  'Happy Feet',
#  'Ice Age: The Meltdown',
#  'Casino Royale',
#  'The Pursuit of Happyness',
#  'Over the Hedge',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'Click',
#  'Mission: Impossible III',
#  'The Departed',
#  'Borat',
#  'The Devil Wears Prada',
#  'The Break-Up',
#  'Dreamgirls',
#  'Scary Movie 4',
#  'Failure to Launch',
#  'Inside Man',
#  'Open Season',
#  'The Santa Clause 3: The Escape Clause',
#  "Charlotte's Web",
#  'The Pink Panther',
#  'Eight Below',
#  'Saw III',
#  'Nacho Libre',
#  'You, Me and Dupree',
#  'Eragon',
#  'Monster House',
#  'Barnyard: The Original Party Animals',
#  'Jackass: Number Two',
#  'R.V.',
#  'V for Vendetta',
#  'World Trade Center',
#  'Rocky Balboa',
#  "Big Momma's House 2",
#  'Step Up',
#  'Flushed Away',
#  'DÃ©jÃ\xa0 Vu',
#  'Miami Vice',
#  'The Holiday',
#  "Madea's Family Reunion",
#  'The Fast and the Furious: Tokyo Drift',
#  'Underworld: Evolution',
#  'The Shaggy Dog',
#  'Poseidon',
#  'The Good Shepherd',
#  'Little Miss Sunshine',
#  'The Benchwarmers',
#  'Curious George',
#  'Little Man',
#  'Invincible',
#  'Blood Diamond',
#  'The Queen',
#  'The Guardian',
#  'The Omen',
#  'Final Destination 3',
#  'The Prestige',
#  'The Lake House',
#  'Hoodwinked',
#  'Apocalypto',
#  'Firewall',
#  'Date Movie',
#  'When a Stranger Calls',
#  'Hostel',
#  'Nanny McPhee',
#  'Silent Hill',
#  'Deep Sea 3D',
#  'We Are Marshall',
#  'Glory Road',
#  'Lady in the Water',
#  'The Hills Have Eyes',
#  'John Tucker Must Die',
#  'Stranger Than Fiction',
#  'The Illusionist',
#  'The Texas Chainsaw Massacre: The Beginning',
#  'The Grudge 2',
#  'Gridiron Gang',
#  'Last Holiday',
#  'El Laberinto del Fauno',
#  'The Nativity Story',
#  'Man of the Year',
#  'The Wild',
#  '16 Blocks',
#  'Accepted',
#  'The Sentinel',
#  'Children of Men',
#  'Deck the Halls',
#  'Take the Lead',
#  'Babel',
#  'Snakes on a Plane',
#  "She's the Man",
#  'Flags of Our Fathers',
#  'United 93',
#  'Employee of the Month',
#  'Garfield: A Tail of Two Kitties',
#  'The Ant Bully',
#  'Crank',
#  'Stick It',
#  'The Descent',
#  'Thank You For Smoking',
#  'Huo Yuan Jia',
#  'The Wicker Man',
#  'Clerks II',
#  'An Inconvenient Truth',
#  'The Covenant',
#  'Stay Alive',
#  'The Black Dahlia',
#  'My Super Ex-Girlfriend',
#  'Lucky Number Slevin',
#  'Waist Deep',
#  'ATL',
#  'Flicka',
#  'A Prairie Home Companion',
#  'Pulse',
#  'Beerfest',
#  'Akeelah and the Bee',
#  'The Marine',
#  'Aquamarine',
#  'Ultraviolet',
#  'School for Scoundrels',
#  'The Last King of Scotland',
#  'Notes on a Scandal',
#  'Just My Luck',
#  'Annapolis',
#  'Unaccompanied Minors',
#  'An American Haunting',
#  'Black Christmas',
#  'Marie Antoinette',
#  'Larry the Cable Guy: Health Inspector',
#  'See No Evil',
#  'Tristan & Isolde',
#  "Everyone's Hero",
#  'Hollywoodland',
#  'Letters from Iwo Jima',
#  'One Night with the King',
#  'Friends with Money',
#  'Flyboys',
#  'How to Eat Fried Worms',
#  'Volver',
#  'Bon Cop, Bad Cop',
#  'Idlewild',
#  'Freedomland',
#  'Tom yum goong',
#  'Zoom',
#  'End of the Spear',
#  "Dave Chappelle's Block Party",
#  'The Last Kiss',
#  'Something New',
#  'Material Girls',
#  'Bobby',
#  'Scoop',
#  'Roving Mars',
#  'Facing the Giants',
#  'The Fountain',
#  'Transamerica',
#  'Tenacious D in: The Pick of Destiny',
#  'Hoot',
#  'The Painted Veil',
#  'The Night Listener',
#  'Slither',
#  'The Return',
#  'Doogal',
#  'A Good Year',
#  'American Dreamz',
#  "All the King's Men",
#  'Phat Girlz',
#  'Turistas',
#  'Crossover',
#  'Running With Scissors',
#  'Running Scared',
#  'Man cheng jin dai huang jin jia',
#  'Grandmaâ\x80\x99s Boy',
#  'Basic Instinct 2',
#  'For Your Consideration',
#  'Water',
#  'A Scanner Darkly',
#  'Little Children',
#  'La science des rÃªves',
#  "Let's Go to Prison",
#  'Keeping Up with the Steins',
#  'Catch a Fire',
#  'Goal! The Dream Begins',
#  'Van Wilder Deux: The Rise of Taj',
#  'Trailer Park Boys: The Movie',
#  'Venus',
#  'Harsh Times',
#  'Art School Confidential',
#  'Kabhi Alvida Naa Kehna',
#  'Boynton Beach Club',
#  'Wordplay',
#  'Miss Potter',
#  'Tsotsi',
#  'Peaceful Warrior',
#  'La mujer de mi hermano',
#  'The History Boys',
#  'Half Nelson',
#  'Dhoom 2',
#  'The Lost City',
#  'Le Secret de ma Mere',
#  'BloodRayne',
#  'After Dark HorrorFest 2006: 8 Films to Die For',
#  'Don',
#  'Perfume: The Story of a Murderer',
#  'Lage Raho Munna Bhai',
#  'Rang De Basanti',
#  'Fanaa',
#  'Brick',
#  'Strangers with Candy',
#  'Shortbus',
#  'The Proposition',
#  'Why We Fight',
#  'Neil Young: Heart of Gold',
#  'Kinky Boots',
#  'Sweet Land',
#  'Quinceanera',
#  'Who Killed the Electric Car?',
#  'Keeping Mum',
#  'Trust the Man',
#  'Nochnoy dozor',
#  'Krrish',
#  'The Notorious Bettie Page',
#  'Romeo et Juliette',
#  'The Work and the Glory III: A House Divided',
#  'The Good German',
#  'Tristram Shandy: A Cock and Bull Story',
#  'Omkara',
#  'Shut Up and Sing',
#  'The Celestine Prophecy',
#  'Banlieue 13',
#  'Find Me Guilty',
#  'Infamous',
#  'The U.S. vs John Lennon',
#  'Joyeux NoÃ«l',
#  "Leonard Cohen: I'm Your Man",
#  'Hard Candy',
#  'Fast Food Nation',
#  'Breaking and Entering',
#  'Jesus Camp',
#  'Vers le sud',
#  'Looking for Comedy in the Muslim World',
#  'Inland Empire',
#  'Guadalupe',
#  'Factotum',
#  'Bhagam Bhag',
#  "L'armÃ©e des ombres",
#  'Ask the Dust',
#  'Sophie Scholl - Die letzten Tage',
#  'Imagine Me & You',
#  'Wu ji',
#  'Alex Rider: Operation Stormbreaker',
#  'Another Gay Movie',
#  'Lassie',
#  "L'Enfant",
#  'Jaan-E-Maan',
#  'Viva Pedro',
#  'Down in the Valley',
#  'Changing Times',
#  'Casa de Areia',
#  'Death of a President',
#  'A Guide to Recognizing Your Saints',
#  'Umrao Jaan',
#  "Artie Lange's Beer League",
#  'Church Ball',
#  'Romeo & Juliet: Sealed with a Kiss',
#  'The Heart of the Game',
#  'Idiocracy',
#  "Don't Come Knocking",
#  'Sketches of Frank Gehry',
#  'The Second Chance',
#  'When Do We Eat?',
#  'Conversations with God',
#  'The Oh in Ohio',
#  'Preaching to the Choir',
#  'The Quiet',
#  'Conversations with Other Women',
#  'Shadowboxer',
#  'Copying Beethoven',
#  "Marilyn Hotchkiss' Ballroom Dancing and Charm S…",
#  'Chup Chup Ke',
#  'The Devil and Daniel Johnston',
#  'Gabrielle',
#  'Zinda',
#  'Cheech',
#  'The Road to Guantanamo',
#  'Russian Dolls',
#  'IndigÃ¨nes',
#  "Don't Trip, He Ain't Through With Me Yet",
#  'Adam & Steve',
#  'This Film is Not Yet Rated',
#  'Kabul Express',
#  'Sukob',
#  'Taxi No. 9 2 11: Nau Do Gyarah',
#  'Seres Queridos',
#  'The King',
#  'American Hardcore',
#  'Night of the Living Dead 3-D',
#  'Dirty',
#  'Old Joy',
#  'The War Tapes',
#  "Love's Abiding Joy",
#  'Qian li zou dan qi',
#  'Broken Bridges',
#  'Humko Deewana Kar Gaye',
#  'La Moustache',
#  '49 Up',
#  'Driving Lessons',
#  'Wah-Wah',
#  'Drawing Restraint 9',
#  'Confetti',
#  'The Beauty Academy of Kabul',
#  'Unidentified',
#  'FUR: An Imaginary Portrait of Diane Arbus',
#  'A Good Woman',
#  'Shaadi Karke Phas Gaye Yaar',
#  'Wassup Rockers',
#  'Le petit lieutenant',
#  'Chinjeolhan geumjassi',
#  'The Journals of Knud Rasmussen',
#  'Tamara',
#  'Malamaal Weekly',
#  'Iraq in Fragments',
#  'Deliver Us From Evil',
#  'Sherrybaby',
#  'Fateless',
#  'The Puffy Chair',
#  'On a Clear Day',
#  'Queens',
#  'The Bridge',
#  'Our Brand is Crisis',
#  'Cocaine Cowboys',
#  "Awesome: I F%!#in' Shot That",
#  'The 2005 Academy Award Nominated Short Films',
#  'Lonesome Jim',
#  'The Mostly Unfabulous Social Life of Ethan Green',
#  'Zui Hao De Shi Guang',
#  'Pyare Mohan',
#  'The Great New Wonderful',
#  'Off the Black',
#  "Jonestown: The Life and Death of People's Temple",
#  'Temporada de patos',
#  'Bubble',
#  'Once in a Lifetime: the Extraordinary Story of …',
#  'Kekexili',
#  'Haven',
#  'Cave of the Yellow Dog',
#  'Taepung',
#  'Clean',
#  'What the Bleep?: Down the Rabbit Hole',
#  'Stolen',
#  'Edmond',
#  'Cidade Baixa',
#  'Game 6',
#  'The Groomsmen',
#  'Unknown White Male',
#  'Flannel Pajamas',
#  '13 Tzameti',
#  'Iklimler',
#  'Come Early Morning',
#  'Le temps qui reste',
#  'Sir! No Sir!',
#  'I Am a Sex Addict',
#  "La Demoiselle d'honneur",
#  'Winter Passing',
#  'Shaadi Se Pehle',
#  'Kaptein Sabeltann',
#  'Look Both Ways',
#  "2 ou 3 choses que je sais d'elle",
#  'Mutual Appreciation',
#  'Al Franken: God Spoke',
#  'Red Doors',
#  'Twelve and Holding',
#  'Sommersturm',
#  'Black Gold',
#  'Somersault',
#  'Wondrous Oblivion',
#  'Being Cyrus',
#  'America: Freedom to Fascism',
#  'Color of the Cross',
#  '51 Birch Street',
#  'Ten Items or Less',
#  'Lemming',
#  'Moartea domnului Lazarescu',
#  'Suits on the Loose',
#  'El Topo',
#  'Manderlay',
#  'Samoan Wedding',
#  'LÃ¼ cao di',
#  'Batalla en el cielo',
#  'Crossing the Bridge: The Sound of Istanbul',
#  'Renaissance',
#  'Cavite',
#  'Beowulf & Grendel',
#  'Inconscientes',
#  'Tideland',
#  'Absolute Wilson',
#  'Darshan, The Embrace',
#  'Vajra Sky Over Tibet',
#  'Poster Boy',
#  'Aurora Borealis',
#  "D'Lucky Ones",
#  'El Aura',
#  'Feast',
#  'Anthony Kaun Hai',
#  'That Man: Peter Berlin',
#  '10th & Wolf',
#  'Kalamazoo?',
#  'Mannat',
#  'La Petite JÃ©rusalem',
#  'Plagues and Pleasures on the Salton Sea',
#  'Screamers',
#  'Moonlight',
#  'The Motel',
#  "Mini's First Time",
#  'Shakespeare Behind Bars',
#  'SÃ\xadlenÃ\xad',
#  'Tibet: A Buddhist Trilogy',
#  'The Zodiac',
#  'Candy',
#  'Brothers of the Head',
#  'Azumi',
#  'Commune',
#  'Rape of the Soul',
#  'Stoned',
#  'Family Law',
#  'Kakushi-ken: oni no tsume',
#  'Eating Out 2: Sloppy Seconds',
#  'Monkey Warfare',
#  'Man Push Cart',
#  'Been Rich All My Life',
#  'Bubot Niyar',
#  'Swimmers',
#  'The Real Dirt on Farmer John',
#  'My Country My Country',
#  'Sisters in Law',
#  'Loverboy',
#  'Free Zone',
#  'Nathalie...',
#  'Excellent Cadavers',
#  'Pyar Ke Side Effects',
#  'Standing Still',
#  'Princesas',
#  'RomÃ¡ntico',
#  'Broken Sky',
#  'The Piano Tuner of EarthQuakes',
#  'The Heart is Deceitful Above All Things',
#  'MÃ¤nner wie wir',
#  'The Blossoming of Maximo Oliveros',
#  "Boy's Briefs 4",
#  'Who Gets to Call It Art?',
#  'Jazireh ahani',
#  "Don't Tell",
#  'Mozart and the Whale',
#  'Abduction: The Megumi Yokota Story',
#  'Trudell',
#  'Khosla Ka Ghosla',
#  'Unknown',
#  'Hood of Horror',
#  'Te doy mis ojos',
#  'Henri Cartier-Bresson - Biographie eines Blicks',
#  'Wrestling with Angels',
#  'Odete',
#  'Un aÃ±o sin amor',
#  'The Strange Case of Dr. Jekyll and Mr. Hyde',
#  'American Gun',
#  'Quand la mer monte...',
#  'Islam: What the West Needs to Know',
#  'Ambrose Bierce: Civil War Stories',
#  'Little Fish',
#  'F*ck',
#  'Giuliani Time',
#  'Yang Ban XI',
#  'Killer Diller',
#  'The Secret Life of Words',
#  'Words of My Perfect Teacher',
#  'The Ground Truth: After the Killing Ends',
#  'The Dead Girl',
#  'El Perro',
#  '4',
#  'Suicide Killers',
#  'Cruel World',
#  'Film Geek',
#  'Ever Again',
#  'So Much So Fast',
#  'Cautiva',
#  "April's Shower",
#  'I Like Killling Flies',
#  'Matthew Barney: No Restraint',
#  'Sleeping Dogs Lie',
#  'Ondskan',
#  'My First Wedding',
#  'Shem',
#  'Through the Fire',
#  'Opal Dream',
#  "The Devil's Miner",
#  'The Architect',
#  'Who the #$^% is Jackson Pollock?',
#  'Spider-Man 3',
#  'Shrek the Third',
#  'Transformers',
#  'Pirates of the Caribbean: At Worldâ\x80\x99s End',
#  'Harry Potter and the Order of the Phoenix',
#  'I am Legend',
#  'The Bourne Ultimatum',
#  'National Treasure: Book of Secrets',
#  'Alvin and the Chipmunks',
#  '300',
#  'Ratatouille',
#  'The Simpsons Movie',
#  'Wild Hogs',
#  'Knocked Up',
#  'Juno',
#  'Rush Hour 3',
#  'Live Free or Die Hard',
#  'Fantastic Four: Rise of the Silver Surfer',
#  'American Gangster',
#  'Enchanted',
#  'Bee Movie',
#  'Superbad',
#  'I Now Pronounce You Chuck and Larry',
#  'Hairspray',
#  'Blades of Glory',
#  "Ocean's Thirteen",
#  'Ghost Rider',
#  'Evan Almighty',
#  'Meet the Robinsons',
#  'Norbit',
#  'The Bucket List',
#  'The Game Plan',
#  'Beowulf',
#  'Bridge to Terabithia',
#  'Disturbia',
#  'No Country for Old Men',
#  'Fred Claus',
#  '1408',
#  'The Golden Compass',
#  'Charlie Wilsonâ\x80\x99s War',
#  'Saw IV',
#  'Stomp the Yard',
#  'Surfâ\x80\x99s Up',
#  'Halloween',
#  'Why Did I Get Married?',
#  'TMNT',
#  'P.S. I Love You',
#  '3:10 to Yuma',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Atonement',
#  'Resident Evil: Extinction',
#  'Music and Lyrics',
#  'Are We Done Yet?',
#  'This Christmas',
#  'Michael Clayton',
#  'Premonition',
#  'Dan in Real Life',
#  'The Kingdom',
#  'Shooter',
#  'License to Wed',
#  'Underdog',
#  'No Reservations',
#  'Because I Said So',
#  'Aliens vs. Predator - Requiem',
#  'The Water Horse: Legend of the Deep',
#  'There Will Be Blood',
#  'Epic Movie',
#  'Hitman',
#  '30 Days of Night',
#  'Fracture',
#  'Stardust',
#  'The Brave One',
#  'The Heartbreak Kid',
#  'Freedom Writers',
#  "Smokin' Aces",
#  'The Messengers',
#  'The Number 23',
#  'Good Luck Chuck',
#  'Mr. Beanâ\x80\x99s Holiday',
#  'Zodiac',
#  'Breach',
#  'Balls of Fury',
#  "Mr. Magorium's Wonder Emporium",
#  'August Rush',
#  "Daddy's Little Girls",
#  'The Great Debaters',
#  '28 Weeks Later',
#  'We Own the Night',
#  'Mr. Brooks',
#  'Hannibal Rising',
#  'The Nanny Diaries',
#  'Mr. Woodcock',
#  'The Mist',
#  'Nancy Drew',
#  'The Reaping',
#  'Grindhouse',
#  'Sicko',
#  'Across the Universe',
#  'Perfect Stranger',
#  'Sea Monsters: A Prehistoric Adventure',
#  'Hot Fuzz',
#  'War',
#  'The Last Mimzy',
#  'Amazing Grace',
#  'The Hills Have Eyes II',
#  'The Invisible',
#  'Reno 911!: Miami',
#  'Gone Baby Gone',
#  'Reign Over Me',
#  'Waitress',
#  'Vacancy',
#  'Georgia Rule',
#  'Becoming Jane',
#  'Into the Wild',
#  'Walk Hard: The Dewey Cox Story',
#  'Next',
#  'Hostel: Part II',
#  'Eastern Promises',
#  'Dead Silence',
#  'The Hitcher',
#  'Elizabeth: The Golden Age',
#  "Happily N'Ever After",
#  'The Kite Runner',
#  'Catch and Release',
#  'Alpha Dog',
#  'Arthur et les Minimoys',
#  'The Invasion',
#  'Lions for Lambs',
#  'Awake',
#  'Hot Rod',
#  'Firehouse Dog',
#  'The Namesake',
#  'The Comebacks',
#  'Daddy Day Camp',
#  "Shoot 'Em Up",
#  'I Think I Love My Wife',
#  'Evening',
#  'The Darjeeling Limited',
#  'Sydney White',
#  'Das Leben der Anderen',
#  'In the Land of Women',
#  'The Astronaut Farmer',
#  'Dragon Wars: D-War',
#  'Primeval',
#  'La MÃ´me',
#  'Pathfinder',
#  'Bratz',
#  'Rendition',
#  'Death Sentence',
#  'Once',
#  'Black Snake Moan',
#  'A Mighty Heart',
#  'The Seeker: The Dark is Rising',
#  'Death at a Funeral',
#  'Code Name: The Cleaner',
#  'Delta Farce',
#  'Bella',
#  'El Cantante',
#  'Martian Child',
#  'The Condemned',
#  'I Know Who Killed Me',
#  'The Hoax',
#  'El orfanato',
#  "Before the Devil Knows You're Dead",
#  'Pride',
#  'Bug',
#  'Redline',
#  'In the Valley of Elah',
#  'The Savages',
#  'P2',
#  'Le Scaphandre et le Papillon',
#  'Lars and the Real Girl',
#  'The Last Legion',
#  'Feel the Noise',
#  'The Perfect Holiday',
#  'Lucky You',
#  "Who's Your Caddy?",
#  'Aqua Teen Hunger Force Colon Movie Film for The…',
#  'Rescue Dawn',
#  "Paris, je t'aime",
#  'Love in the Time of Cholera',
#  'Se jie',
#  'The Lookout',
#  'Away From Her',
#  'Talk to Me',
#  'Kickin It Old Skool',
#  'Persepolis',
#  'Deux jours Ã\xa0 Paris',
#  'Zwartboek',
#  'Iâ\x80\x99m Not There',
#  'Ladron que roba a ladron',
#  'The Assassination of Jesse James by the Coward …',
#  'Nitro',
#  'Sunshine',
#  'Om Shanti Om',
#  'The Jane Austen Book Club',
#  'Blood and Chocolate',
#  'Feast of Love',
#  'The Ultimate Gift',
#  'Things We Lost in the Fire',
#  'Resurrecting the Champ',
#  'The Ex',
#  'Illegal Tender',
#  'Gracie',
#  'Ma Fille, Mon Ange',
#  'Captivity',
#  'You Kill Me',
#  'La doublure',
#  'Gwoemul',
#  'Guru',
#  'Avenue Montaigne',
#  'Margot at the Wedding',
#  'Salaam-e-Ishq (A Tribute to Love)',
#  'The Wind That Shakes the Barley',
#  'Factory Girl',
#  'Year of the Dog',
#  'Efter brylluppet',
#  "L'Ã¢ge des tÃ©nÃ¨bres",
#  'No End In Sight',
#  'Mon meilleur ami',
#  'Heyy Babyy',
#  'Eklavya - The Royal Guard',
#  'The Abandoned',
#  'Slow Burn',
#  'Taare Zameen Par',
#  'Namastey London',
#  'The Final Season',
#  'In the Shadow of the Moon',
#  'Chak De India',
#  'Silk',
#  'Bhool Bhulaiyaa',
#  'September Dawn',
#  'Nuovomondo',
#  'Partner',
#  'Ma Tante Aline',
#  'Skinwalkers',
#  'Thr3e',
#  "Goya's Ghosts",
#  'Broken English',
#  'The Ten Commandments',
#  'Provoked: A True Story',
#  'Starting Out in the Evening',
#  'The Brothers Solomon',
#  'Saawariya',
#  'Paprika',
#  'The Hunting Party',
#  'After Dark HorrorFest 2007: 8 More Films to Die…',
#  'Ta Ra Rum Pum',
#  'Control',
#  'Sharkwater',
#  'Wie man sein leben kocht',
#  'Arctic Tale',
#  'Sarah Landon and the Paranormal Hour',
#  'Die groÃ\x9fe Stille',
#  'The Ten',
#  'Rocket Science',
#  '11th Hour',
#  'Jhoom Barabar Jhoom',
#  'Lady Chatterley',
#  'Cheeni Kum',
#  'Laaga Chunari Mein Daag',
#  'The King of Kong',
#  'MoliÃ¨re',
#  'Journey from the Fall',
#  'Italianetz',
#  'Romance and Cigarettes',
#  'U-Carmen e-Khayelitsha',
#  'Aaja Nachle',
#  'Joshua',
#  'DOA: Dead or Alive',
#  'Dnevnoy dozor',
#  'Brooklyn Rules',
#  'Wristcutters: A Love Story',
#  'When the Road Bends: Tales of a Gypsy Caravan',
#  'The Singing Revolution',
#  'Seraphim Falls',
#  'Interview',
#  'Jindabyne',
#  'Manufactured Landscapes',
#  'The Last Sin Eater',
#  'Introducing the Dwights',
#  'Sleuth',
#  '2006 Academy Award Nominated Short Films',
#  'This is England',
#  'For the Bible Tells Me So',
#  'Constellation',
#  'Chalk',
#  'God Grew Tired of Us: The Story of Lost Boys of…',
#  'Crazy Love',
#  'Fido',
#  'Nos Voisins Dhantsu',
#  'Passage to Zarahemla',
#  'Shootout at Lokhandwala',
#  'Ten Canoes',
#  'Southland Tales',
#  'Deep Water',
#  'King of California',
#  'Honeydripper',
#  'The TV Set',
#  'Steep',
#  'NoÃ«lle',
#  'Joe Strummer: The Future is Unwritten',
#  'Gandhi, My Father',
#  'Youth Without Youth',
#  'O Jerusalem',
#  'My Kid Could Paint That',
#  'Brand Upon the Brain!',
#  'In Search of Mozart',
#  '10 Questions for the Dalai Lama',
#  'Aida at La Scala',
#  'Surviving My Mother',
#  'Eagle vs Shark',
#  'Ira and Abby',
#  'Boy Culture',
#  'Dus Kahaniyaan',
#  'Starter for Ten',
#  'First Snow',
#  'Trade',
#  'Believe in Me',
#  'La Tourneuse de Pages',
#  'Milarepa',
#  'Angel-A',
#  'A Man Named Pearl',
#  'Cama adentro',
#  'What Would Jesus Buy?',
#  'I Want Someone To Eat Cheese With',
#  'Lonely Hearts',
#  'Vitus',
#  'Offside',
#  'Pete Seeger: The Power of Song',
#  'An Unreasonable Man',
#  'Hatchet',
#  'The Flying Scotsman',
#  'Hollywood Dreams',
#  'La faute Ã\xa0 Fidel',
#  'Dhamaal',
#  'Holly',
#  'Outsourced',
#  'Vanaja',
#  'Nanking',
#  'Ha-Buah',
#  'Red Road',
#  'Music Within',
#  'ShowBusiness: The Road to Broadway',
#  'Life in a... Metro',
#  'Memories of Tomorrow',
#  'The Salon',
#  'Severance',
#  'Coeurs',
#  'The Devil Came on Horseback',
#  'Americanizing Shelley',
#  'The Wendell Baker Story',
#  'Fay Grim',
#  'Dhan Dhana Dhan Goal',
#  'Manda Bala',
#  'David & Layla',
#  'War Dance',
#  'Rise: Blood Hunter',
#  'Bamako',
#  'Darfur Now',
#  'Jimmy Carter: Man From Plains',
#  'I Have Never Forgotten You: The Life & Legacy o…',
#  'Tortilla Heaven',
#  'Mr. Untouchable',
#  'Return with Honor: A Missionary Homecoming',
#  'Reservation Road',
#  'Self Medicated',
#  'King Corn',
#  'The List',
#  'Civic Duty',
#  'Dialogue avec mon jardinier',
#  'Dedication',
#  'A fost sau n-a fost?',
#  'Puccini for Beginners',
#  'Blind Dating',
#  'Delirious',
#  'Klimt',
#  'Fierce People',
#  'Revolver',
#  'Black Sheep',
#  'Le Doulos',
#  'Kurt Cobain: About a Son',
#  'The Treatment',
#  'Comedy of Power',
#  'The Walker',
#  'Nomad',
#  'Radiant City',
#  'Christmas in Wonderland',
#  'Fah talai jone',
#  'Nishabd',
#  'Eye of the Dolphin',
#  'Gray Matters',
#  'Air Guitar Nation',
#  'Colour Me Kubrick: A True...ish Story',
#  'Pierrot le fou',
#  'Zoo',
#  'Behind the Mask: The Rise of Leslie Vernon',
#  'Lagerfeld Confidential',
#  'Diggers',
#  'Redacted',
#  'El Violin',
#  'Right at Your Door',
#  'Even Money',
#  'The Nines',
#  'Dans Paris',
#  'Nue propriÃ©tÃ©',
#  'My Brother',
#  'Bushi no ichibun',
#  'Islander',
#  'Quebec sur Ordonnace',
#  'Maxed Out: Hard Times, Easy Credit and the Era …',
#  'Hak se wui yi wo wai kwai',
#  'Finishing the Game',
#  'Fong juk',
#  'Strength and Honour',
#  'Direktøren for det hele',
#  'Grace Is Gone',
#  'Local Color',
#  'Transformation: The Life & Legacy of Werner Erhard',
#  'Fakers',
#  'Alice Neel',
#  'The Situation',
#  'Ghosts of CitÃ© Soleil',
#  "L'avocat de la terreur",
#  'Two Weeks',
#  'December Boys',
#  'The Hip Hop Project',
#  'Shotgun Stories',
#  'Randy and the Mob',
#  'Home of the Brave',
#  'Grbavica',
#  'Billy the Kid',
#  'Moving McAllister',
#  'Colma: The Musical',
#  'Beyond the Gates',
#  'Controlled Chaos',
#  'The Life of Reilly',
#  'Yiddish Theater: A Love Story',
#  'The Cats of Mirikitan',
#  'Moondance Alexander',
#  'Fighting Words',
#  'Canvas',
#  'Bon Jovi: Lost Highway - The Concert',
#  'Black Friday',
#  'La Chinoise',
#  'The Tracey Fragments',
#  'The Last Winter',
#  'Sacco and Vanzetti',
#  'Day Night Day Night',
#  'Wind Chill',
#  'The Hottest State',
#  'Falling for Grace',
#  'Gringo Wedding',
#  'Snow Cake',
#  'Ils',
#  'Stephanie Daley',
#  'Naked Boys Singing',
#  'Beed-e majnoon',
#  'Cashback',
#  'Lake of Fire',
#  'Forever',
#  'Hattrick',
#  'Arnolds Park',
#  'In Between Days',
#  'The Sensation of Sight',
#  'Il Ne Faut Jurer de Rien',
#  'Les anges exterminateurs',
#  'Xiang ri kui',
#  'The Tripper',
#  'Hannah Takes the Stairs',
#  'The Good Night',
#  'Rails & Ties',
#  'Amu',
#  'La Strada di Levi',
#  'Great World of Sound',
#  'Sing Now or Forever Hold Your Peace',
#  'The Last Hangman',
#  "Dr. Bronner's Magic Soapbox",
#  'Imaginary Witness: Hollywood and the Holocaust',
#  'Dreaming Lhasa',
#  'Flandres',
#  'Karov La Bayit',
#  'Arranged',
#  "Sommer '04",
#  'Meeting Resistance',
#  'Dirty Laundry',
#  "L'Iceberg",
#  'Czech Dream',
#  "Everything's Gone Green",
#  'Hei yan quan',
#  'Steal a Pencil for Me',
#  'What Love Is',
#  'Itty Bitty Titty Committee',
#  'Chacun sa nuit',
#  'Hei Wong Ji Wong',
#  'Flying: Confessions of a Free Woman',
#  '7 dÃ\xadas',
#  'American Cannibal',
#  'Sang sattawat',
#  'The Amateurs',
#  ...]

# %%
# Dependencies
import requests
from config import api_key

url = "http://www.omdbapi.com/?apikey=" + api_key + "&t="

responses = []

for movie in scrape():
    movie_data = requests.get(url + movie).json()
    responses.append(movie_data)

# %%
responses
# Out:
# [{'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Night at the Museum',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '22 Dec 2006',
#   'Runtime': '108 min',
#   'Genre': 'Adventure, Comedy, Family',
#   'Director': 'Shawn Levy',
#   'Writer': 'Robert Ben Garant, Thomas Lennon, Milan Trenc',
#   'Actors': 'Ben Stiller, Carla Gugino, Ricky Gervais',
#   'Plot': 'A newly recruited night security guard at the Museum of Natural History discovers that an ancient curse causes the animals and exhibits on display to come to life and wreak havoc.',
#   'Language': 'English, Italian, Hebrew',
#   'Country': 'United States, United Kingdom',
#   'Awards': '2 wins & 8 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyOTM4MDMxN15BMl5BanBnXkFtZTcwODg5NTQzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#    {'Source': 'Metacritic', 'Value': '48/100'}],
#   'Metascore': '48',
#   'imdbRating': '6.4',
#   'imdbVotes': '327,040',
#   'imdbID': 'tt0477347',
#   'Type': 'movie',
#   'DVD': '24 Apr 2007',
#   'BoxOffice': '$250,863,268',
#   'Production': '20th Century Fox, 21 Laps Entertainment, 1492 Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Cars',
#   'Year': '2006',
#   'Rated': 'G',
#   'Released': '09 Jun 2006',
#   'Runtime': '117 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'John Lasseter, Joe Ranft',
#   'Writer': 'John Lasseter, Joe Ranft, Jorgen Klubien',
#   'Actors': 'Owen Wilson, Bonnie Hunt, Paul Newman',
#   'Plot': 'A hot-shot race-car named Lightning McQueen gets waylaid in Radiator Springs, where he finds the true meaning of friendship and family.',
#   'Language': 'English, Italian, Japanese, Yiddish',
#   'Country': 'United States',
#   'Awards': 'Nominated for 2 Oscars. 28 wins & 34 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5NzY0MzA2MV5BMl5BanBnXkFtZTYwNDc3NTc2._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '73/100'}],
#   'Metascore': '73',
#   'imdbRating': '7.1',
#   'imdbVotes': '387,337',
#   'imdbID': 'tt0317219',
#   'Type': 'movie',
#   'DVD': '07 Nov 2006',
#   'BoxOffice': '$244,082,982',
#   'Production': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'X-Men: The Last Stand',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '26 May 2006',
#   'Runtime': '104 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Director': 'Brett Ratner',
#   'Writer': 'Simon Kinberg, Zak Penn',
#   'Actors': 'Patrick Stewart, Hugh Jackman, Halle Berry',
#   'Plot': 'The human government develops a cure for mutations, and Jean Gray becomes a darker uncontrollable persona called the Phoenix who allies with Magneto, causing escalation into an all-out battle for the X-Men.',
#   'Language': 'English',
#   'Country': 'United States, United Kingdom, Canada',
#   'Awards': '7 wins & 40 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDBhNDJiMWEtOTg4Yi00NTYzLWEzOGMtMjNmNjAxNTBlMzY3XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Metascore': '58',
#   'imdbRating': '6.7',
#   'imdbVotes': '496,162',
#   'imdbID': 'tt0376994',
#   'Type': 'movie',
#   'DVD': '03 Oct 2006',
#   'BoxOffice': '$234,362,462',
#   'Production': 'Marvel Enterprises, Twentieth Century Fox',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Da Vinci Code',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '19 May 2006',
#   'Runtime': '149 min',
#   'Genre': 'Mystery, Thriller',
#   'Director': 'Ron Howard',
#   'Writer': 'Akiva Goldsman, Dan Brown',
#   'Actors': 'Tom Hanks, Audrey Tautou, Jean Reno',
#   'Plot': 'A murder inside the Louvre, and clues in Da Vinci paintings, lead to the discovery of a religious mystery protected by a secret society for two thousand years, which could shake the foundations of Christianity.',
#   'Language': 'English, French, Latin, Spanish',
#   'Country': 'United States, Malta, France, United Kingdom',
#   'Awards': '8 wins & 21 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIxMjQyMTc3Nl5BMl5BanBnXkFtZTcwMTA1MDUzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '26%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Metascore': '46',
#   'imdbRating': '6.6',
#   'imdbVotes': '414,805',
#   'imdbID': 'tt0382625',
#   'Type': 'movie',
#   'DVD': '14 Nov 2006',
#   'BoxOffice': '$217,536,138',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Superman Returns',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '28 Jun 2006',
#   'Runtime': '154 min',
#   'Genre': 'Action, Sci-Fi',
#   'Director': 'Bryan Singer',
#   'Writer': 'Michael Dougherty, Dan Harris, Bryan Singer',
#   'Actors': 'Brandon Routh, Kevin Spacey, Kate Bosworth',
#   'Plot': 'Superman returns to Earth after spending five years in space examining his homeworld Krypton. But he finds things have changed while he was gone, and he must once again prove himself important to the world.',
#   'Language': 'English, German, French',
#   'Country': 'United States, Australia',
#   'Awards': 'Nominated for 1 Oscar. 12 wins & 47 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzY2ZDQ2MTctYzlhOC00MWJhLTgxMmItMDgzNDQwMDdhOWI2XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Metascore': '72',
#   'imdbRating': '6.0',
#   'imdbVotes': '276,121',
#   'imdbID': 'tt0348150',
#   'Type': 'movie',
#   'DVD': '28 Nov 2006',
#   'BoxOffice': '$200,081,192',
#   'Production': 'Warner Bros.',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Happy Feet',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '17 Nov 2006',
#   'Runtime': '108 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'George Miller, Warren Coleman, Judy Morris',
#   'Writer': 'George Miller, John Collee, Judy Morris',
#   'Actors': 'Elijah Wood, Brittany Murphy, Hugh Jackman',
#   'Plot': 'Into the world of the Emperor Penguins, who find their soul mates through song, a penguin is born who cannot sing. But he can tap dance something fierce!',
#   'Language': 'English',
#   'Country': 'United States, Australia, New Zealand, Antarctica',
#   'Awards': 'Won 1 Oscar. 20 wins & 26 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyNTkxMjUwMV5BMl5BanBnXkFtZTcwMDQ2NTU0MQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Metascore': '77',
#   'imdbRating': '6.4',
#   'imdbVotes': '176,567',
#   'imdbID': 'tt0366548',
#   'Type': 'movie',
#   'DVD': '27 Mar 2007',
#   'BoxOffice': '$198,000,317',
#   'Production': 'Village Roadshow Prod., Kennedy Miller Productions',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Ice Age: The Meltdown',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '31 Mar 2006',
#   'Runtime': '91 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'Carlos Saldanha',
#   'Writer': 'Peter Gaulke, Gerry Swallow, Jim Hecht',
#   'Actors': 'Ray Romano, John Leguizamo, Denis Leary',
#   'Plot': 'Manny, Sid, and Diego discover that the ice age is coming to an end, and join everybody for a journey to higher ground. On the trip, they discover that Manny, in fact, is not the last of the woolly mammoths.',
#   'Language': 'English',
#   'Country': 'United States, United Kingdom, Australia',
#   'Awards': '8 wins & 16 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwODg3OTAxMl5BMl5BanBnXkFtZTcwMjg2NjYyMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '60/100'}],
#   'Metascore': '60',
#   'imdbRating': '6.8',
#   'imdbVotes': '265,775',
#   'imdbID': 'tt0438097',
#   'Type': 'movie',
#   'DVD': '21 Nov 2006',
#   'BoxOffice': '$195,330,621',
#   'Production': 'Fox Animation Studios, 20th Century Fox',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Casino Royale',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '17 Nov 2006',
#   'Runtime': '144 min',
#   'Genre': 'Action, Adventure, Thriller',
#   'Director': 'Martin Campbell',
#   'Writer': 'Neal Purvis, Robert Wade, Paul Haggis',
#   'Actors': 'Daniel Craig, Eva Green, Judi Dench',
#   'Plot': 'After earning 00 status and a licence to kill, secret agent James Bond sets out on his first mission as 007. Bond must defeat a private banker funding terrorists in a high-stakes game of poker at Casino Royale, Montenegro.',
#   'Language': 'English, Serbian, German, Italian, French',
#   'Country': 'United Kingdom, Czech Republic, United States, Germany, Bahamas',
#   'Awards': '27 wins & 44 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMDI5ZWJhOWItYTlhOC00YWNhLTlkNzctNDU5YTI1M2E1MWZhXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '80/100'}],
#   'Metascore': '80',
#   'imdbRating': '8.0',
#   'imdbVotes': '600,982',
#   'imdbID': 'tt0381061',
#   'Type': 'movie',
#   'DVD': '13 Mar 2007',
#   'BoxOffice': '$167,445,960',
#   'Production': 'Metro-Goldwyn-Mayer, Sony Pictures Entertainment, Eon Productions Ltd.',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Pursuit of Happyness',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '15 Dec 2006',
#   'Runtime': '117 min',
#   'Genre': 'Biography, Drama',
#   'Director': 'Gabriele Muccino',
#   'Writer': 'Steve Conrad',
#   'Actors': 'Will Smith, Thandiwe Newton, Jaden Smith',
#   'Plot': "A struggling salesman takes custody of his son as he's poised to begin a life-changing professional career.",
#   'Language': 'English, Cantonese',
#   'Country': 'United States',
#   'Awards': 'Nominated for 1 Oscar. 12 wins & 26 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5NjQ0NDI3NF5BMl5BanBnXkFtZTcwNDI0MjEzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#    {'Source': 'Metacritic', 'Value': '64/100'}],
#   'Metascore': '64',
#   'imdbRating': '8.0',
#   'imdbVotes': '472,431',
#   'imdbID': 'tt0454921',
#   'Type': 'movie',
#   'DVD': '27 Mar 2007',
#   'BoxOffice': '$163,566,459',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Over the Hedge',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '19 May 2006',
#   'Runtime': '83 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'Tim Johnson, Karey Kirkpatrick',
#   'Writer': 'Len Blum, Lorne Cameron, David Hoselton',
#   'Actors': 'Bruce Willis, Garry Shandling, Steve Carell',
#   'Plot': 'A scheming raccoon fools a mismatched family of forest creatures into helping him repay a debt of food, by invading the new suburban sprawl that popped up while they were hibernating...and learns a lesson about family himself.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '7 wins & 26 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwMTQxNTcwOF5BMl5BanBnXkFtZTcwMzQ1NzUzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Metascore': '67',
#   'imdbRating': '6.7',
#   'imdbVotes': '166,208',
#   'imdbID': 'tt0327084',
#   'Type': 'movie',
#   'DVD': '17 Oct 2006',
#   'BoxOffice': '$155,019,340',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Talladega Nights: The Ballad of Ricky Bobby',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '04 Aug 2006',
#   'Runtime': '108 min',
#   'Genre': 'Comedy, Sport',
#   'Director': 'Adam McKay',
#   'Writer': 'Will Ferrell, Adam McKay',
#   'Actors': 'Will Ferrell, John C. Reilly, Sacha Baron Cohen',
#   'Plot': "Number one NASCAR driver Ricky Bobby stays atop the heap thanks to a pact with his best friend and teammate, Cal Naughton, Jr. But when a French Formula One driver, makes his way up the ladder, Ricky Bobby's talent and devotion are p",
#   'Language': 'English, French',
#   'Country': 'United States',
#   'Awards': '8 wins & 9 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzAzOTk1OTIyM15BMl5BanBnXkFtZTcwNDIzNTQzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '6.6',
#   'imdbVotes': '174,810',
#   'imdbID': 'tt0415306',
#   'Type': 'movie',
#   'DVD': '12 Dec 2006',
#   'BoxOffice': '$148,213,377',
#   'Production': 'Apatow Productions, High, Wide and Handsome Inc.',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Click',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '23 Jun 2006',
#   'Runtime': '107 min',
#   'Genre': 'Comedy, Drama, Fantasy',
#   'Director': 'Frank Coraci',
#   'Writer': "Steve Koren, Mark O'Keefe",
#   'Actors': 'Adam Sandler, Kate Beckinsale, Christopher Walken',
#   'Plot': 'A workaholic architect finds a universal remote that allows him to fast-forward and rewind to different parts of his life. Complications arise when the remote starts to overrule his choices.',
#   'Language': 'English, Portuguese, Japanese',
#   'Country': 'United States',
#   'Awards': 'Nominated for 1 Oscar. 3 wins & 12 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA1MTUxNDY4NzReQTJeQWpwZ15BbWU2MDE3ODAxNw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '34%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Metascore': '45',
#   'imdbRating': '6.4',
#   'imdbVotes': '316,733',
#   'imdbID': 'tt0389860',
#   'Type': 'movie',
#   'DVD': '10 Oct 2006',
#   'BoxOffice': '$137,355,633',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Mission: Impossible III',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '05 May 2006',
#   'Runtime': '126 min',
#   'Genre': 'Action, Adventure, Thriller',
#   'Director': 'J.J. Abrams',
#   'Writer': 'Alex Kurtzman, Roberto Orci, J.J. Abrams',
#   'Actors': 'Tom Cruise, Michelle Monaghan, Ving Rhames',
#   'Plot': 'IMF agent Ethan Hunt comes into conflict with a dangerous and sadistic arms dealer who threatens his life and his fiancée in response.',
#   'Language': 'English, Italian, Mandarin, Cantonese, German, Czech',
#   'Country': 'United States, Germany, China, Italy',
#   'Awards': '7 wins & 14 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOThhNTA1YjItYzk2Ny00M2Y1LWJlYWUtZDQyZDU0YmY5Y2M5XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '6.9',
#   'imdbVotes': '340,696',
#   'imdbID': 'tt0317919',
#   'Type': 'movie',
#   'DVD': '30 Oct 2006',
#   'BoxOffice': '$134,029,801',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Departed',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '06 Oct 2006',
#   'Runtime': '151 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'Director': 'Martin Scorsese',
#   'Writer': 'William Monahan, Alan Mak, Felix Chong',
#   'Actors': 'Leonardo DiCaprio, Matt Damon, Jack Nicholson',
#   'Plot': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   'Language': 'English, Cantonese',
#   'Country': 'United States, Hong Kong',
#   'Awards': 'Won 4 Oscars. 97 wins & 141 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#    {'Source': 'Metacritic', 'Value': '85/100'}],
#   'Metascore': '85',
#   'imdbRating': '8.5',
#   'imdbVotes': '1,243,116',
#   'imdbID': 'tt0407887',
#   'Type': 'movie',
#   'DVD': '13 Feb 2007',
#   'BoxOffice': '$132,384,315',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '03 Nov 2006',
#   'Runtime': '84 min',
#   'Genre': 'Comedy',
#   'Director': 'Larry Charles',
#   'Writer': 'Sacha Baron Cohen, Anthony Hines, Peter Baynham',
#   'Actors': 'Sacha Baron Cohen, Ken Davitian, Luenell',
#   'Plot': 'Kazakh TV talking head Borat is dispatched to the United States to report on the greatest country in the world. With a documentary crew in tow, Borat becomes more interested in locating and marrying Pamela Anderson.',
#   'Language': 'English, Romanian, Hebrew, Polish, Armenian',
#   'Country': 'United States, United Kingdom, Kazakhstan',
#   'Awards': 'Nominated for 1 Oscar. 20 wins & 34 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MTQ3NDQ4Ml5BMl5BanBnXkFtZTcwOTQ3OTQzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '89/100'}],
#   'Metascore': '89',
#   'imdbRating': '7.3',
#   'imdbVotes': '391,422',
#   'imdbID': 'tt0443453',
#   'Type': 'movie',
#   'DVD': '06 Mar 2007',
#   'BoxOffice': '$128,505,958',
#   'Production': 'Gold/Miller Productions',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Devil Wears Prada',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '30 Jun 2006',
#   'Runtime': '109 min',
#   'Genre': 'Comedy, Drama',
#   'Director': 'David Frankel',
#   'Writer': 'Aline Brosh McKenna, Lauren Weisberger',
#   'Actors': 'Anne Hathaway, Meryl Streep, Adrian Grenier',
#   'Plot': 'A smart but sensible new graduate lands a job as an assistant to Miranda Priestly, the demanding editor-in-chief of a high fashion magazine.',
#   'Language': 'English, French',
#   'Country': 'United States, France',
#   'Awards': 'Nominated for 2 Oscars. 19 wins & 53 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZjQ3ZTIzOTItMGNjNC00MWRmLWJlMGEtMjJmMDM5ZDIzZGM3XkEyXkFqcGdeQXVyMTkzODUwNzk@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Metascore': '62',
#   'imdbRating': '6.9',
#   'imdbVotes': '389,952',
#   'imdbID': 'tt0458352',
#   'Type': 'movie',
#   'DVD': '12 Dec 2006',
#   'BoxOffice': '$124,740,460',
#   'Production': 'Fox 2000 Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Break-Up',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '02 Jun 2006',
#   'Runtime': '106 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Peyton Reed',
#   'Writer': 'Jeremy Garelick, Jay Lavender, Vince Vaughn',
#   'Actors': 'Jennifer Aniston, Vince Vaughn, Jon Favreau',
#   'Plot': "In a bid to keep their luxurious condo from their significant other, a couple's break-up proceeds to get uglier and nastier by the moment.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '3 wins & 5 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM1YjVhNTMtZTEyZi00ODk3LWI4NDItZWUyZTA1ODM3Zjk4XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '34%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Metascore': '45',
#   'imdbRating': '5.8',
#   'imdbVotes': '129,124',
#   'imdbID': 'tt0452594',
#   'Type': 'movie',
#   'DVD': '17 Oct 2006',
#   'BoxOffice': '$118,703,275',
#   'Production': 'Universal Pictures, Mosaic Media Group',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Dreamgirls',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '25 Dec 2006',
#   'Runtime': '130 min',
#   'Genre': 'Drama, Music, Musical',
#   'Director': 'Bill Condon',
#   'Writer': 'Tom Eyen, Bill Condon',
#   'Actors': 'Beyoncé, Jamie Foxx, Eddie Murphy',
#   'Plot': 'A trio of black female soul singers cross over to the pop charts in the early 1960s, facing their own personal struggles along the way.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'Won 2 Oscars. 67 wins & 92 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1MzIwNDQyNl5BMl5BanBnXkFtZTcwNDEwNzYyMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#    {'Source': 'Metacritic', 'Value': '76/100'}],
#   'Metascore': '76',
#   'imdbRating': '6.5',
#   'imdbVotes': '71,601',
#   'imdbID': 'tt0443489',
#   'Type': 'movie',
#   'DVD': '01 May 2007',
#   'BoxOffice': '$103,365,956',
#   'Production': 'DreamWorks SKG, Paramount',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Scary Movie 4',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '14 Apr 2006',
#   'Runtime': '83 min',
#   'Genre': 'Comedy',
#   'Director': 'David Zucker',
#   'Writer': 'Craig Mazin, Jim Abrahams, Pat Proft',
#   'Actors': 'Anna Faris, Regina Hall, Craig Bierko',
#   'Plot': 'Cindy finds out the house she lives in is haunted by a little boy and goes on a quest to find out who killed him and why. Also, Alien "Tr-iPods" are invading the world and she has to uncover the secret in order to stop them.',
#   'Language': 'English, Japanese',
#   'Country': 'United States, Canada',
#   'Awards': '1 win & 3 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZmFkMzc2NTctN2U1Ni00MzE5LWJmMzMtYWQ4NjQyY2MzYmM1XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#    {'Source': 'Metacritic', 'Value': '40/100'}],
#   'Metascore': '40',
#   'imdbRating': '5.1',
#   'imdbVotes': '117,207',
#   'imdbID': 'tt0362120',
#   'Type': 'movie',
#   'DVD': '15 Aug 2006',
#   'BoxOffice': '$90,710,620',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Failure to Launch',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '10 Mar 2006',
#   'Runtime': '97 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Tom Dey',
#   'Writer': 'Tom J. Astle, Matt Ember',
#   'Actors': 'Matthew McConaughey, Sarah Jessica Parker, Kathy Bates',
#   'Plot': "A thirty-something is still living with his parents until they hire an interventionist to help him graduate out of the house. That's when the fun begins.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '5 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0OTc2MDQ3NV5BMl5BanBnXkFtZTcwNDUwMjEzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '24%'},
#    {'Source': 'Metacritic', 'Value': '47/100'}],
#   'Metascore': '47',
#   'imdbRating': '5.6',
#   'imdbVotes': '77,460',
#   'imdbID': 'tt0427229',
#   'Type': 'movie',
#   'DVD': '27 Jun 2006',
#   'BoxOffice': '$88,715,192',
#   'Production': 'Paramount, Scott Rudin Productions',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Inside Man',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '24 Mar 2006',
#   'Runtime': '129 min',
#   'Genre': 'Crime, Drama, Mystery',
#   'Director': 'Spike Lee',
#   'Writer': 'Russell Gewirtz',
#   'Actors': 'Denzel Washington, Clive Owen, Jodie Foster',
#   'Plot': "A police detective, a bank robber, and a high-power broker enter high-stakes negotiations after the criminal's brilliant heist spirals into a hostage situation.",
#   'Language': 'English, Albanian, Spanish, Polish',
#   'Country': 'United States',
#   'Awards': '5 wins & 12 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjc4MjA2ZDgtOGY3YS00NDYzLTlmNTEtYWMxMzcwZjgzYWNjXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#    {'Source': 'Metacritic', 'Value': '76/100'}],
#   'Metascore': '76',
#   'imdbRating': '7.6',
#   'imdbVotes': '354,013',
#   'imdbID': 'tt0454848',
#   'Type': 'movie',
#   'DVD': '08 Aug 2006',
#   'BoxOffice': '$88,513,495',
#   'Production': 'Universal Pictures, 40 Acres &amp; A Mule Filmworks, Imagine Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Open Season',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '29 Sep 2006',
#   'Runtime': '86 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'Roger Allers, Jill Culton, Anthony Stacchi',
#   'Writer': 'Steve Bencich, Ron J. Friedman, Nat Mauldin',
#   'Actors': 'Ashton Kutcher, Martin Lawrence, Debra Messing',
#   'Plot': 'Boog, a domesticated 900lb. Grizzly bear, finds himself stranded in the woods 3 days before Open Season. Forced to rely on Elliot, a fast-talking mule deer, the two form an unlikely friendship and must quickly rally other forest anim',
#   'Language': 'English',
#   'Country': 'United States, Canada',
#   'Awards': '1 win & 10 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwOTg2MjU0OV5BMl5BanBnXkFtZTcwMzIzNTQzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '48%'},
#    {'Source': 'Metacritic', 'Value': '49/100'}],
#   'Metascore': '49',
#   'imdbRating': '6.1',
#   'imdbVotes': '91,221',
#   'imdbID': 'tt0400717',
#   'Type': 'movie',
#   'DVD': '30 Jan 2007',
#   'BoxOffice': '$85,105,259',
#   'Production': 'Columbia Pictures, Sony Pictures Animation',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Santa Clause 3: The Escape Clause',
#   'Year': '2006',
#   'Rated': 'G',
#   'Released': '03 Nov 2006',
#   'Runtime': '92 min',
#   'Genre': 'Adventure, Comedy, Family',
#   'Director': 'Michael Lembeck',
#   'Writer': 'Ed Decter, John J. Strauss, Leo Benvenuti',
#   'Actors': 'Tim Allen, Martin Short, Elizabeth Mitchell',
#   'Plot': 'Santa, a.k.a. Scott Calvin, is faced with double-duty: how to keep his new family happy and how to stop Jack Frost from taking over Christmas.',
#   'Language': 'English',
#   'Country': 'United States, Canada',
#   'Awards': '4 wins & 9 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI4ODQ4MzgzMl5BMl5BanBnXkFtZTcwODc5NTUzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '17%'},
#    {'Source': 'Metacritic', 'Value': '32/100'}],
#   'Metascore': '32',
#   'imdbRating': '4.8',
#   'imdbVotes': '34,810',
#   'imdbID': 'tt0452681',
#   'Type': 'movie',
#   'DVD': '20 Nov 2007',
#   'BoxOffice': '$84,500,122',
#   'Production': 'Walt Disney Pictures, Boxing Cat Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "Charlotte's Web",
#   'Year': '2006',
#   'Rated': 'G',
#   'Released': '15 Dec 2006',
#   'Runtime': '97 min',
#   'Genre': 'Adventure, Comedy, Family',
#   'Director': 'Gary Winick',
#   'Writer': 'Susannah Grant, Karey Kirkpatrick, Earl Hamner Jr.',
#   'Actors': 'Dakota Fanning, Julia Roberts, Oprah Winfrey',
#   'Plot': 'Wilbur the pig is scared of the end of the season, because he knows that come that time, he will end up on the dinner table. He hatches a plan with Charlotte, a spider that lives in his pen, to ensure that this will never happen.',
#   'Language': 'English',
#   'Country': 'United States, Germany, Australia',
#   'Awards': '10 wins & 11 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5MTUzMTAzMl5BMl5BanBnXkFtZTcwNTE0NTcyMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Metascore': '68',
#   'imdbRating': '6.3',
#   'imdbVotes': '39,478',
#   'imdbID': 'tt0413895',
#   'Type': 'movie',
#   'DVD': '03 Apr 2007',
#   'BoxOffice': '$82,985,708',
#   'Production': 'Nickelodeon Movies, Paramount Pictures, Walden Media, Kerner Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Pink Panther',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '10 Feb 2006',
#   'Runtime': '93 min',
#   'Genre': 'Adventure, Comedy, Crime',
#   'Director': 'Shawn Levy',
#   'Writer': 'Len Blum, Steve Martin, Michael Saltzman',
#   'Actors': 'Steve Martin, Kevin Kline, Jean Reno',
#   'Plot': 'Bumbling Inspector Clouseau must solve the murder of a famous soccer coach and find out who stole the infamous Pink Panther diamond.',
#   'Language': 'English',
#   'Country': 'United States, Czech Republic',
#   'Awards': '1 win & 8 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNGI2MjVlNzEtZDg1ZS00MGU1LWFhNTQtNzMwZDViOWRkNzhkXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '21%'},
#    {'Source': 'Metacritic', 'Value': '38/100'}],
#   'Metascore': '38',
#   'imdbRating': '5.7',
#   'imdbVotes': '84,059',
#   'imdbID': 'tt0383216',
#   'Type': 'movie',
#   'DVD': '13 Jun 2006',
#   'BoxOffice': '$82,226,474',
#   'Production': 'Metro Goldwyn Mayer',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Eight Below',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '17 Feb 2006',
#   'Runtime': '120 min',
#   'Genre': 'Adventure, Drama, Family',
#   'Director': 'Frank Marshall',
#   'Writer': 'David DiGilio, Toshirô Ishidô, Koreyoshi Kurahara',
#   'Actors': 'Paul Walker, Jason Biggs, Bruce Greenwood',
#   'Plot': 'Brutal cold forces two Antarctic explorers to leave their team of sled dogs behind as they fend for their survival.',
#   'Language': 'English',
#   'Country': 'United States, Canada, Antarctica',
#   'Awards': '2 wins & 2 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExMjAwNzE0N15BMl5BanBnXkFtZTYwMDY4NDk2._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '64/100'}],
#   'Metascore': '64',
#   'imdbRating': '7.3',
#   'imdbVotes': '63,021',
#   'imdbID': 'tt0397313',
#   'Type': 'movie',
#   'DVD': '20 Jun 2006',
#   'BoxOffice': '$81,612,565',
#   'Production': 'Touchstone Pictures, Mandeville Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Saw III',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '27 Oct 2006',
#   'Runtime': '108 min',
#   'Genre': 'Crime, Horror, Mystery',
#   'Director': 'Darren Lynn Bousman',
#   'Writer': 'Leigh Whannell, James Wan',
#   'Actors': 'Tobin Bell, Shawnee Smith, Angus Macfadyen',
#   'Plot': 'Jigsaw abducts a doctor in order to keep himself alive while he watches his new apprentice put an unlucky citizen named Jeff through a brutal test.',
#   'Language': 'English',
#   'Country': 'Canada, United States',
#   'Awards': '1 win & 9 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI5MjkzMDkzNF5BMl5BanBnXkFtZTcwMDg2NTUzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#    {'Source': 'Metacritic', 'Value': '48/100'}],
#   'Metascore': '48',
#   'imdbRating': '6.2',
#   'imdbVotes': '186,013',
#   'imdbID': 'tt0489270',
#   'Type': 'movie',
#   'DVD': '23 Jan 2007',
#   'BoxOffice': '$80,238,724',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Nacho Libre',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '16 Jun 2006',
#   'Runtime': '92 min',
#   'Genre': 'Comedy, Family, Sport',
#   'Director': 'Jared Hess',
#   'Writer': 'Jared Hess, Jerusha Hess, Mike White',
#   'Actors': 'Jack Black, Ana de la Reguera, Héctor Jiménez',
#   'Plot': 'Berated all his life by those around him, a monk follows his dream and dons a mask to moonlight as a Luchador (Mexican wrestler).',
#   'Language': 'English, Spanish',
#   'Country': 'United States, Mexico',
#   'Awards': '1 win & 11 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BN2ZkNDgxMjMtZmRiYS00MzFkLTk5ZjgtZDJkZWMzYmUxYjg4XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '40%'},
#    {'Source': 'Metacritic', 'Value': '52/100'}],
#   'Metascore': '52',
#   'imdbRating': '5.8',
#   'imdbVotes': '84,722',
#   'imdbID': 'tt0457510',
#   'Type': 'movie',
#   'DVD': '24 Oct 2006',
#   'BoxOffice': '$80,197,993',
#   'Production': 'Paramount Pictures, Black &amp; White Productions, Nickelodeon Movies',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'You, Me and Dupree',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '14 Jul 2006',
#   'Runtime': '110 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Writer': 'Michael LeSieur',
#   'Actors': 'Kate Hudson, Owen Wilson, Matt Dillon',
#   'Plot': "A best man (Wilson) stays on as a houseguest with the newlyweds, much to the couple's annoyance.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '3 wins & 2 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUxOTg0MzczOV5BMl5BanBnXkFtZTcwODk1MTQzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '20%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Metascore': '46',
#   'imdbRating': '5.6',
#   'imdbVotes': '80,037',
#   'imdbID': 'tt0463034',
#   'Type': 'movie',
#   'DVD': '21 Nov 2006',
#   'BoxOffice': '$75,628,110',
#   'Production': 'Universal Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Eragon',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '15 Dec 2006',
#   'Runtime': '104 min',
#   'Genre': 'Action, Adventure, Family',
#   'Director': 'Stefen Fangmeier',
#   'Writer': 'Peter Buchman, Christopher Paolini',
#   'Actors': 'Ed Speleers, Sienna Guillory, Jeremy Irons',
#   'Plot': "In his homeland of Alagaesia, a farm boy happens upon a dragon's egg -- a discovery that leads him on a predestined journey where he realizes he's the one person who can defend his home against an evil king.",
#   'Language': 'English',
#   'Country': 'United States, United Kingdom, Hungary',
#   'Awards': '1 win & 6 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzMyMGI1N2UtNzc5YS00OGNkLTg1OTktMTNkMmY2Zjk1NTQxXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#    {'Source': 'Metacritic', 'Value': '38/100'}],
#   'Metascore': '38',
#   'imdbRating': '5.1',
#   'imdbVotes': '124,246',
#   'imdbID': 'tt0449010',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': '$75,030,163',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Monster House',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '21 Jul 2006',
#   'Runtime': '91 min',
#   'Genre': 'Animation, Comedy, Family',
#   'Director': 'Gil Kenan',
#   'Writer': 'Dan Harmon, Rob Schrab, Pamela Pettler',
#   'Actors': 'Mitchel Musso, Sam Lerner, Spencer Locke',
#   'Plot': "Three teens discover that their neighbor's house is really a living, breathing, scary monster.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'Nominated for 1 Oscar. 4 wins & 23 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIzNjE1NDg1N15BMl5BanBnXkFtZTcwOTg2NTMzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Metascore': '68',
#   'imdbRating': '6.6',
#   'imdbVotes': '108,043',
#   'imdbID': 'tt0385880',
#   'Type': 'movie',
#   'DVD': '24 Oct 2006',
#   'BoxOffice': '$73,661,010',
#   'Production': 'ImageMovers',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Jackass Number Two',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '22 Sep 2006',
#   'Runtime': '92 min',
#   'Genre': 'Documentary, Action, Comedy',
#   'Director': 'Jeff Tremaine',
#   'Writer': 'Jeff Tremaine, Spike Jonze, Johnny Knoxville',
#   'Actors': 'Johnny Knoxville, Steve-O, Chris Pontius',
#   'Plot': 'Chris Pontius, Johnny Knoxville, Steve-O, Bam Margera, and the whole crew return to the screen to raise the stakes higher than ever before.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 nomination',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzgzNDYyOTcxNl5BMl5BanBnXkFtZTcwODczNzUzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '7.0',
#   'imdbVotes': '69,411',
#   'imdbID': 'tt0493430',
#   'Type': 'movie',
#   'DVD': '06 Dec 2005',
#   'BoxOffice': '$72,778,712',
#   'Production': 'Paramount Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'R.V. 2015',
#   'Year': '2015',
#   'Rated': 'N/A',
#   'Released': '01 Jan 2015',
#   'Runtime': 'N/A',
#   'Genre': 'Reality-TV',
#   'Director': 'N/A',
#   'Writer': 'N/A',
#   'Actors': 'Anthony Franzzo, Erica Franzzo, Blair Herter, Vivica Johnson',
#   'Plot': '3 families search for their perfect RV.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZDU3N2I2MzUtOGYxMS00YzA3LTgyMzQtNGViZGE1NmU4ZDU3XkEyXkFqcGdeQXVyMjg3OTQ2NTI@._V1_SX300.jpg',
#   'Ratings': [],
#   'Metascore': 'N/A',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'imdbID': 'tt4328500',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'V for Vendetta',
#   'Year': '2005',
#   'Rated': 'R',
#   'Released': '17 Mar 2006',
#   'Runtime': '132 min',
#   'Genre': 'Action, Drama, Sci-Fi',
#   'Director': 'James McTeigue',
#   'Writer': 'Lilly Wachowski, Lana Wachowski, David Lloyd',
#   'Actors': 'Hugo Weaving, Natalie Portman, Rupert Graves',
#   'Plot': 'In a future British tyranny, a shadowy freedom fighter, known only by the alias of "V," plots to overthrow it with the help of a young woman.',
#   'Language': 'English',
#   'Country': 'United States, United Kingdom, Germany',
#   'Awards': '7 wins & 29 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTI5ODc3NzExNV5BMl5BanBnXkFtZTcwNzYxNzQzMw@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Metascore': '62',
#   'imdbRating': '8.1',
#   'imdbVotes': '1,067,948',
#   'imdbID': 'tt0434409',
#   'Type': 'movie',
#   'DVD': '01 Aug 2006',
#   'BoxOffice': '$70,511,035',
#   'Production': 'Virtual Studios, Warner Bros., Anarchos Productions Inc., Silver Pictures',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'World Trade Center',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '09 Aug 2006',
#   'Runtime': '129 min',
#   'Genre': 'Drama, History, Thriller',
#   'Director': 'Oliver Stone',
#   'Writer': 'Andrea Berloff, John McLoughlin, Donna McLoughlin',
#   'Actors': 'Nicolas Cage, Michael Peña, Maria Bello',
#   'Plot': 'Two Port Authority police officers become trapped under the rubble of the World Trade Center.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '4 wins & 12 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIxMzE5ODEwOV5BMl5BanBnXkFtZTcwMzM3MzIzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Metascore': '66',
#   'imdbRating': '5.9',
#   'imdbVotes': '81,393',
#   'imdbID': 'tt0469641',
#   'Type': 'movie',
#   'DVD': '12 Dec 2006',
#   'BoxOffice': '$70,278,893',
#   'Production': 'Paramount Pictures, Double Feature Films, Intermedia Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Rocky Balboa',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '20 Dec 2006',
#   'Runtime': '102 min',
#   'Genre': 'Action, Drama, Sport',
#   'Director': 'Sylvester Stallone',
#   'Writer': 'Sylvester Stallone',
#   'Actors': 'Sylvester Stallone, Antonio Tarver, Milo Ventimiglia',
#   'Plot': "Thirty years after the ring of the first bell, Rocky Balboa comes out of retirement and dons his gloves for his final fight against the reigning heavyweight champ Mason 'The Line' Dixon.",
#   'Language': 'English, Spanish',
#   'Country': 'United States',
#   'Awards': '4 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNWIyNmQyNjctYmVmMS00MGI4LWIxMmUtNjA0ODYzOTA0Yjk0L2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '77%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Metascore': '63',
#   'imdbRating': '7.1',
#   'imdbVotes': '209,830',
#   'imdbID': 'tt0479143',
#   'Type': 'movie',
#   'DVD': '20 Mar 2007',
#   'BoxOffice': '$70,270,943',
#   'Production': 'Rogue Marble, Columbia Pictures Corporation, Metro-Goldwyn-Mayer, Chartoff-Winkler Productions, Revolution Studios, United Artists',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "Big Momma's House 2",
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '27 Jan 2006',
#   'Runtime': '99 min',
#   'Genre': 'Comedy, Crime',
#   'Director': 'John Whitesell',
#   'Writer': 'Don Rhymer, Darryl Quarles',
#   'Actors': 'Martin Lawrence, Emily Procter, Nia Long',
#   'Plot': "An FBI agent reprises his disguise as a corpulent old lady and takes a job as a nanny in a crime suspect's house.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 win & 5 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZjZmYTQ3OTktODkzYy00YmQxLTgxMjEtY2ZkZDY4MDYzNDNmXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '5%'},
#    {'Source': 'Metacritic', 'Value': '34/100'}],
#   'Metascore': '34',
#   'imdbRating': '4.8',
#   'imdbVotes': '42,181',
#   'imdbID': 'tt0421729',
#   'Type': 'movie',
#   'DVD': '09 May 2006',
#   'BoxOffice': '$70,165,972',
#   'Production': 'New Regency Pictures, Deep River Productions, Epsilon Motion Pictures, Regency Enterprises, Friendly Productions, Twentieth Century Fox, Firm Films, Runteldat Entertainment',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Step Up',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '11 Aug 2006',
#   'Runtime': '104 min',
#   'Genre': 'Crime, Drama, Music',
#   'Director': 'Anne Fletcher',
#   'Writer': 'Duane Adler, Melissa Rosenberg',
#   'Actors': 'Channing Tatum, Jenna Dewan, Damaine Radcliff',
#   'Plot': 'Tyler Gage receives the opportunity of a lifetime after vandalizing a performing arts school, gaining him the chance to earn a scholarship and dance with an up and coming dancer, Nora.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 win & 3 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODEzMzVhODgtOTc1NS00MmY3LWI3OGUtN2ZjNDEwM2ExZjJlXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '21%'},
#    {'Source': 'Metacritic', 'Value': '48/100'}],
#   'Metascore': '48',
#   'imdbRating': '6.5',
#   'imdbVotes': '113,949',
#   'imdbID': 'tt0462590',
#   'Type': 'movie',
#   'DVD': '19 Dec 2006',
#   'BoxOffice': '$65,328,121',
#   'Production': 'Summit Entertainment, Eketahuna LLC',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Flushed Away',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '03 Nov 2006',
#   'Runtime': '85 min',
#   'Genre': 'Animation, Action, Adventure',
#   'Director': 'David Bowers, Sam Fell',
#   'Writer': 'Dick Clement, Ian La Frenais, Christopher Lloyd',
#   'Actors': 'Hugh Jackman, Kate Winslet, Ian McKellen',
#   'Plot': 'The story of an uptown rat that gets flushed down the toilet from his penthouse apartment, ending in the sewers of London, where he has to learn a whole new and different way of life.',
#   'Language': 'English',
#   'Country': 'United Kingdom, United States, Australia, France, Ireland',
#   'Awards': '7 wins & 15 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI1MzE1MDk2N15BMl5BanBnXkFtZTYwMjEwMzI3._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '74/100'}],
#   'Metascore': '74',
#   'imdbRating': '6.6',
#   'imdbVotes': '118,698',
#   'imdbID': 'tt0424095',
#   'Type': 'movie',
#   'DVD': '20 Feb 2007',
#   'BoxOffice': '$64,665,672',
#   'Production': 'Aardman Animations, DreamWorks Animation, DreamWorks SKG',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Miami Vice',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '28 Jul 2006',
#   'Runtime': '132 min',
#   'Genre': 'Action, Crime, Drama',
#   'Director': 'Michael Mann',
#   'Writer': 'Michael Mann, Anthony Yerkovich',
#   'Actors': 'Colin Farrell, Jamie Foxx, Gong Li',
#   'Plot': 'Based on the 1980s TV action/drama, this update focuses on vice detectives Crockett and Tubbs as their respective personal and professional lives become dangerously intertwined.',
#   'Language': 'English, Spanish',
#   'Country': 'Germany, United States',
#   'Awards': '1 win & 9 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM4MDQ5MTkxMV5BMl5BanBnXkFtZTcwMTU4MzUzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '46%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Metascore': '65',
#   'imdbRating': '6.0',
#   'imdbVotes': '113,431',
#   'imdbID': 'tt0430357',
#   'Type': 'movie',
#   'DVD': '11 Mar 2008',
#   'BoxOffice': '$63,450,470',
#   'Production': 'Universal Pictures, Michael Mann Productions',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Holiday',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '08 Dec 2006',
#   'Runtime': '136 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Nancy Meyers',
#   'Writer': 'Nancy Meyers',
#   'Actors': 'Kate Winslet, Cameron Diaz, Jude Law',
#   'Plot': "Two women troubled with guy-problems swap homes in each other's countries, where they each meet a local guy and fall in love.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '2 wins & 11 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI1MDk4MzA2OF5BMl5BanBnXkFtZTYwMjQ3NDc3._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '49%'},
#    {'Source': 'Metacritic', 'Value': '52/100'}],
#   'Metascore': '52',
#   'imdbRating': '6.9',
#   'imdbVotes': '261,820',
#   'imdbID': 'tt0457939',
#   'Type': 'movie',
#   'DVD': '13 Mar 2007',
#   'BoxOffice': '$63,224,849',
#   'Production': 'Waverly Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "Madea's Family Reunion",
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '24 Feb 2006',
#   'Runtime': '107 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'Director': 'Tyler Perry',
#   'Writer': 'Tyler Perry',
#   'Actors': 'Tyler Perry, Blair Underwood, Lynn Whitfield',
#   'Plot': 'While planning her family reunion, a pistol-packing grandma must contend with the other dramas on her plate, including the runaway who has been placed under her care, and her love-troubled nieces.',
#   'Language': 'English, Spanish',
#   'Country': 'United States',
#   'Awards': '7 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwODQxOTI4NV5BMl5BanBnXkFtZTYwNzkwNzY3._V1_SX300.jpg',
# ...
#   'Genre': 'Comedy',
#   'Director': 'James Westby',
#   'Writer': 'James Westby',
#   'Actors': 'Melik Malkasian, Ritah Parrish, John Breen',
#   'Plot': 'The story of Scotty Pelk, a socially inept video store clerk who gets fired from his job and becomes a sensation as an online film critic.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM3NjgzMzMyMV5BMl5BanBnXkFtZTgwMzEzNjY2MDE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#    {'Source': 'Metacritic', 'Value': '35/100'}],
#   'Metascore': '35',
#   'imdbRating': '6.1',
#   'imdbVotes': '1,064',
#   'imdbID': 'tt0443506',
#   'Type': 'movie',
#   'DVD': '22 Aug 2006',
#   'BoxOffice': '$17,341',
#   'Production': 'Parkwood East Productions, Portland Narrative Project',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Ever Again',
#   'Year': '2006',
#   'Rated': 'Not Rated',
#   'Released': '08 Dec 2006',
#   'Runtime': '73 min',
#   'Genre': 'Documentary, History, War',
#   'Director': 'Richard Trank',
#   'Writer': 'Marvin Hier, Richard Trank',
#   'Actors': 'Kevin Costner, Dyab Abou Jahjah, Milo Adoner',
#   'Plot': 'Ever Again examines the sweeping resurgence of antisemitism in 21st century Europe and its connection to global terrorism.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMyMDYyMjY2MV5BMl5BanBnXkFtZTcwODE4ODM4Mg@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '50%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.5',
#   'imdbVotes': '61',
#   'imdbID': 'tt0930057',
#   'Type': 'movie',
#   'DVD': '11 Sep 2007',
#   'BoxOffice': '$17,304',
#   'Production': 'Moriah Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'So Much So Fast',
#   'Year': '2006',
#   'Rated': 'Not Rated',
#   'Released': '11 Oct 2006',
#   'Runtime': '87 min',
#   'Genre': 'Documentary',
#   'Director': 'Steven Ascher, Jeanne Jordan',
#   'Writer': 'Steven Ascher, Jeanne Jordan',
#   'Actors': 'Jesse Abbott-Dallamora, Robert Bonazoli, Tyler DiVittorio',
#   'Plot': "A man suffering from Lou Gehrig's disease deals with the woman falling for him and a brother who becomes obsessed with finding a cure.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 win & 2 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0MDE1MTI1MF5BMl5BanBnXkFtZTcwOTc1MDkzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '79/100'}],
#   'Metascore': '79',
#   'imdbRating': '7.5',
#   'imdbVotes': '226',
#   'imdbID': 'tt0492488',
#   'Type': 'movie',
#   'DVD': '30 Sep 2008',
#   'BoxOffice': '$21,525',
#   'Production': 'West City Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Cautiva',
#   'Year': '2003',
#   'Rated': 'Unrated',
#   'Released': '20 Oct 2005',
#   'Runtime': '115 min',
#   'Genre': 'Drama',
#   'Director': 'Gaston Biraben',
#   'Writer': 'Gaston Biraben',
#   'Actors': 'Bárbara Lombardo, Susana Campos, Hugo Arana',
#   'Plot': "Cristina's life is thrown into turmoil when she is suddenly escorted from her strict Catholic school in Buenos Aires and told that she is really Sofía Lombardi, the daughter of activists who disappeared in the '70s. Questioning every",
#   'Language': 'Spanish',
#   'Country': 'Argentina',
#   'Awards': '5 wins & 11 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIwMTY4NjIyOF5BMl5BanBnXkFtZTcwMjg4OTQ0MQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Metascore': '59',
#   'imdbRating': '7.3',
#   'imdbVotes': '688',
#   'imdbID': 'tt0362496',
#   'Type': 'movie',
#   'DVD': '14 Aug 2007',
#   'BoxOffice': '$16,259',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "April's Shower",
#   'Year': '2003',
#   'Rated': 'R',
#   'Released': '26 Jun 2004',
#   'Runtime': '100 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Trish Doolan',
#   'Writer': 'Trish Doolan',
#   'Actors': 'Maria Cina, Trish Doolan, Frank Grillo',
#   'Plot': "Alex is throwing a wedding shower for April. What's revealed at this wacky party, though, is that the two women have a history that goes beyond mere friendship.",
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '4 wins',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyMzQ4Mjc3Nl5BMl5BanBnXkFtZTcwNTkxMDIzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '20%'},
#    {'Source': 'Metacritic', 'Value': '38/100'}],
#   'Metascore': '38',
#   'imdbRating': '5.0',
#   'imdbVotes': '700',
#   'imdbID': 'tt0325007',
#   'Type': 'movie',
#   'DVD': '01 Jan 2010',
#   'BoxOffice': '$16,377',
#   'Production': 'Archer Productions Ltd.',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Response': 'False', 'Error': 'Movie not found!'},
#  {'Title': 'Matthew Barney: No Restraint',
#   'Year': '2006',
#   'Rated': 'N/A',
#   'Released': '04 Oct 2008',
#   'Runtime': '72 min',
#   'Genre': 'Documentary',
#   'Director': 'Alison Chernick',
#   'Writer': 'Alison Chernick',
#   'Actors': 'Matthew Barney, Björk',
#   'Plot': 'How does artist Matthew Barney use 45,000 pounds of petroleum jelly, a factory whaling vessel and traditional Japanese rituals to create his latest art project? Barney plowed the waters off the coast of Nagasaki to film his massive e',
#   'Language': 'Japanese, English',
#   'Country': 'United States',
#   'Awards': '1 nomination',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk1OTY5OTc3Nl5BMl5BanBnXkFtZTcwMDc2Mjc0MQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '50%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Metascore': '59',
#   'imdbRating': '5.9',
#   'imdbVotes': '133',
#   'imdbID': 'tt0481574',
#   'Type': 'movie',
#   'DVD': '01 May 2007',
#   'BoxOffice': '$16,136',
#   'Production': 'Voyeur',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Sleeping Dogs Lie',
#   'Year': '2005',
#   'Rated': 'N/A',
#   'Released': '28 Feb 2005',
#   'Runtime': '89 min',
#   'Genre': 'Short, Drama, Mystery',
#   'Director': 'Stuart Lessner',
#   'Writer': 'Chumahan Bowen',
#   'Actors': 'Brad Wilk, Ed Asner, Maynard James Keenan',
#   'Plot': 'Jeff Hannon (Wilk) from the forever away world of Cincinnati, Ohio has stumbled upon what he believes to be a 25 year old murder in a small Texas town. His ceaseless nightmares compel him to drive to the middle of nowhere town of Bue',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MzMzMjIwOV5BMl5BanBnXkFtZTcwMDU2MzgyMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#   'Metascore': 'N/A',
#   'imdbRating': '6.3',
#   'imdbVotes': '199',
#   'imdbID': 'tt0431405',
#   'Type': 'movie',
#   'DVD': 'N/A',
#   'BoxOffice': 'N/A',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Ondskan',
#   'Year': '2003',
#   'Rated': 'Not Rated',
#   'Released': '26 Sep 2003',
#   'Runtime': '113 min',
#   'Genre': 'Drama',
#   'Director': 'Mikael Håfström',
#   'Writer': 'Jan Guillou, Hans Gunnarsson, Mikael Håfström',
#   'Actors': 'Andreas Wilson, Henrik Lundström, Gustaf Skarsgård',
#   'Plot': 'A teenage boy expelled from school for fighting arrives at a boarding school where the systematic bullying of younger students is encouraged as a means to maintain discipline, and decides to fight back.',
#   'Language': 'Swedish, Finnish',
#   'Country': 'Sweden, Denmark',
#   'Awards': 'Nominated for 1 Oscar. 9 wins & 10 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjE4NzdmOGQtNWNhYS00YmI1LWE5ZTgtY2Q4MmQzODMyNGIzXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#    {'Source': 'Metacritic', 'Value': '61/100'}],
#   'Metascore': '61',
#   'imdbRating': '7.8',
#   'imdbVotes': '36,692',
#   'imdbID': 'tt0338309',
#   'Type': 'movie',
#   'DVD': '27 Jun 2006',
#   'BoxOffice': '$15,530',
#   'Production': 'Moviola Film och Television AB',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'My First Wedding',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '15 Mar 2007',
#   'Runtime': '94 min',
#   'Genre': 'Comedy, Romance',
#   'Director': 'Laurent Firode',
#   'Writer': 'Joan Carr-Wiggin',
#   'Actors': 'Rachael Leigh Cook, Kenny Doughty, Paul Hopkins',
#   'Plot': 'A young carpenter is mistaken for a Catholic priest and sustains the misunderstanding to seduce a girl.',
#   'Language': 'English',
#   'Country': 'Canada, United Kingdom',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgyOTcxNjQ2N15BMl5BanBnXkFtZTcwNDgxNTkzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '0%'}],
#   'Metascore': 'N/A',
#   'imdbRating': '4.8',
#   'imdbVotes': '1,131',
#   'imdbID': 'tt0388288',
#   'Type': 'movie',
#   'DVD': '05 Dec 2006',
#   'BoxOffice': '$14,982',
#   'Production': 'UKFS 4 LLP, My First Wedding Productions, Buccaneer Films, Bespoke Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Shem',
#   'Year': '2004',
#   'Rated': 'Unrated',
#   'Released': 'N/A',
#   'Runtime': '93 min',
#   'Genre': 'Drama',
#   'Director': 'Caroline Roboh',
#   'Writer': 'Caroline Roboh',
#   'Actors': 'Asier Newman, Hadassah Hungar Diamant, Arturo Brachetti',
#   'Plot': "Daniel, a young and arrogant Londoner, is bored to death in his life. His jewish grandmother asks him to go through Europe in order to find his grandfather's grave. Not only will Daniel find his long lost grandfather's trace, but he ",
#   'Language': 'English',
#   'Country': 'Israel, United Kingdom',
#   'Awards': '1 nomination',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTExNzMwMDg4N15BMl5BanBnXkFtZTcwNzk5OTIzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '9%'},
#    {'Source': 'Metacritic', 'Value': '33/100'}],
#   'Metascore': '33',
#   'imdbRating': '4.6',
#   'imdbVotes': '149',
#   'imdbID': 'tt0406214',
#   'Type': 'movie',
#   'DVD': '07 Nov 2006',
#   'BoxOffice': '$14,804',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Through the Fire',
#   'Year': '2005',
#   'Rated': 'N/A',
#   'Released': '21 Apr 2005',
#   'Runtime': '103 min',
#   'Genre': 'Documentary, Biography, Sport',
#   'Director': 'Alistair Christopher, Jonathan Hock',
#   'Writer': 'N/A',
#   'Actors': 'Sebastian Telfair, Rick Pitino, Asher Beard',
#   'Plot': '"Through the Fire" chronicles the journey of Coney Island basketball star, Sebastian Telfair, from famed Lincoln High School straight to the NBA.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 win',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTQ2Mjc1MTc3NV5BMl5BanBnXkFtZTcwMDY4NTMzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Metascore': '65',
#   'imdbRating': '7.1',
#   'imdbVotes': '649',
#   'imdbID': 'tt0457502',
#   'Type': 'movie',
#   'DVD': '14 Mar 2006',
#   'BoxOffice': '$25,752',
#   'Production': 'ESPN, Hock Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Opal Dream',
#   'Year': '2006',
#   'Rated': 'PG',
#   'Released': '22 Nov 2006',
#   'Runtime': '86 min',
#   'Genre': 'Drama, Family',
#   'Director': 'Peter Cattaneo',
#   'Writer': 'Peter Cattaneo, Phil Traill, Ben Rice',
#   'Actors': 'Sapphire Blossom, Christian Byers, Vince Colosimo',
#   'Plot': "A young girl's relationship with her imaginary friends resonates throughout her town in the Australian Outback.",
#   'Language': 'English',
#   'Country': 'Australia, United Kingdom',
#   'Awards': '1 win & 2 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOWE0ZWM3MDgtNjZlMy00YzVmLThiODctNjQ3NTgwYTgzOTA5XkEyXkFqcGdeQXVyNzQ5MzY0NjM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#    {'Source': 'Metacritic', 'Value': '56/100'}],
#   'Metascore': '56',
#   'imdbRating': '6.6',
#   'imdbVotes': '979',
#   'imdbID': 'tt0420835',
#   'Type': 'movie',
#   'DVD': '03 Apr 2007',
#   'BoxOffice': '$14,443',
#   'Production': 'UK Film Council, BBC, South Australian Film Corporation',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': "The Devil's Miner",
#   'Year': '2005',
#   'Rated': 'Not Rated',
#   'Released': '22 Apr 2005',
#   'Runtime': '82 min',
#   'Genre': 'Documentary',
#   'Director': 'Kief Davidson, Richard Ladkani',
#   'Writer': 'Richard Ladkani, Kief Davidson',
#   'Actors': 'N/A',
#   'Plot': "'The Devil's Miner' tells the story of 14-year-old Basilio who worships the devil for protection while working in a Bolivian silver mine to support his family.",
#   'Language': 'Spanish',
#   'Country': 'United States, Germany',
#   'Awards': '9 wins & 6 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc1NDMyMDg0MV5BMl5BanBnXkFtZTcwMzQ4MDAzMQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Metascore': '81',
#   'imdbRating': '7.6',
#   'imdbVotes': '572',
#   'imdbID': 'tt0441001',
#   'Type': 'movie',
#   'DVD': '13 Feb 2015',
#   'BoxOffice': '$14,289',
#   'Production': 'Urban Landscapes Productions',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'The Architect',
#   'Year': '2006',
#   'Rated': 'R',
#   'Released': '26 Apr 2006',
#   'Runtime': '82 min',
#   'Genre': 'Crime, Drama, Romance',
#   'Director': 'Matt Tauber',
#   'Writer': 'David Greig, Matt Tauber',
#   'Actors': 'Anthony LaPaglia, Viola Davis, Isabella Rossellini',
#   'Plot': 'An architect engages in conflict with an activist who lives in a dangerous complex the architect designed.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': '1 nomination',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjcwMzJjOGYtYjAyNi00MGFjLTkzZGYtZjg4ZmQ5NzYzMzczXkEyXkFqcGdeQXVyMjA0MzYwMDY@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '11%'},
#    {'Source': 'Metacritic', 'Value': '47/100'}],
#   'Metascore': '47',
#   'imdbRating': '5.5',
#   'imdbVotes': '1,262',
#   'imdbID': 'tt0466665',
#   'Type': 'movie',
#   'DVD': '05 Dec 2006',
#   'BoxOffice': '$13,737',
#   'Production': 'HDNet, Sly Dog Films',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Who the #$&% Is Jackson Pollock?',
#   'Year': '2006',
#   'Rated': 'PG-13',
#   'Released': '09 Nov 2006',
#   'Runtime': '74 min',
#   'Genre': 'Documentary',
#   'Director': 'Harry Morgan Moses',
#   'Writer': 'Harry Morgan Moses',
#   'Actors': 'Teri Horton, Tod M. Volpe, Ben Heller',
#   'Plot': 'In this documentary, veteran filmmaker Harry Moses exposes the controversy in the world of high priced artwork. He paints a vivid picture of how art is bought and sold in America.',
#   'Language': 'English',
#   'Country': 'United States',
#   'Awards': 'N/A',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcyMTQ1Mzk1OV5BMl5BanBnXkFtZTcwMDM3OTY0MQ@@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#    {'Source': 'Metacritic', 'Value': '70/100'}],
#   'Metascore': '70',
#   'imdbRating': '7.0',
#   'imdbVotes': '1,213',
#   'imdbID': 'tt0487092',
#   'Type': 'movie',
#   'DVD': '01 May 2007',
#   'BoxOffice': '$13,710',
#   'Production': 'New Line Cinema',
#   'Website': 'N/A',
#   'Response': 'True'}]

# %%
import pandas as pd
import csv
import json
